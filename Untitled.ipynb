# %%
import os
from openpyxl import load_workbook
import glob

# %%
filePath1 = './result/' + 'BinhPhuoc' + '/*.jpg'
#filePath2 = './result/' + name + '/*.JPG'
#dataPath = './result/' + name + '/' + name + '.xlsx'
aListFile = [f for f_ in [glob.glob(e) for e in [filePath1]] for f in f_]

# %%
len(aListFile)
# Out:
# 701

# %%
filePath2 = './result/' + 'BinhPhuoc' + '/*.JPG'

# %%
t = glob.glob(filePath2)

# %%
len(t)
# Out:
# 701

# %%
for e in t:
    print(e)
# Out:
# ./result/BinhPhuoc\1 Vũ Xuân Thủy 24-1-1971.jpg
# ./result/BinhPhuoc\10 Bạch Kim Quyên 1993.jpg
# ./result/BinhPhuoc\100 TRỊNH THỊ BÍCH THỦY.jpg
# ./result/BinhPhuoc\101TRẦN THỊ THU HẰNG.jpg
# ./result/BinhPhuoc\102 ĐỖ THỊ MINH.jpg
# ./result/BinhPhuoc\103 HÀ THỊ QUÊ.jpg
# ./result/BinhPhuoc\104 BÙI THỊ KHOÁT.jpg
# ./result/BinhPhuoc\105 LÊ THỊ TUYỀN.jpg
# ./result/BinhPhuoc\106 DƯƠNG THỊ NGOAN.jpg
# ./result/BinhPhuoc\107 NGUYỄN THỊ NGẦN.jpg
# ./result/BinhPhuoc\108 TRẦN THỊ THÊU.jpg
# ./result/BinhPhuoc\109 NGUYỄN THỊ THU.jpg
# ./result/BinhPhuoc\11 BÙI THỊ CHUYÊN.jpg
# ./result/BinhPhuoc\110 NGUYỄN THỊ LIÊN.jpg
# ./result/BinhPhuoc\111 QUÁCH THỊ THẢO.jpg
# ./result/BinhPhuoc\112 TRẦN THỊ HƯƠNG.jpg
# ./result/BinhPhuoc\113 BÙI THỊ DUYÊN.jpg
# ./result/BinhPhuoc\114 NGUYỄN HOÀNG ÁI LINH.jpg
# ./result/BinhPhuoc\115 HOÀNG THỊ PHƯƠNG.jpg
# ./result/BinhPhuoc\116 ĐINH HỒNG HẠNH.jpg
# ./result/BinhPhuoc\117 LÊ THỊ HẢI.jpg
# ./result/BinhPhuoc\118 VŨ THỊ NGUYỆT MINH.jpg
# ...

# %%
t = glob.glob(filePath2)

# %%
len(t)
# Out:
# 701

# %%
for e in t:
    if 'JPG' in e:
        print(e)
# Out:
# ./result/BinhPhuoc\406 Vũ Thị Như Quỳnh.JPG
# ./result/BinhPhuoc\456 Vũ Văn Kiên.JPG
# ./result/BinhPhuoc\710 Trần Xuân Phúc.JPG
